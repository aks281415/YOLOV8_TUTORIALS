# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi

# %%
import os
directory = os.getcwd()
print(directory)
# Out:
# /content

# %%
from ultralytics import YOLO
from IPython.display import display,Image

# %%
# !pip install ultralytics

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/cars.jpg'

# %%
image ='/content/cars.jpg'
Image(filename=image,height=500)

# %%
model = YOLO(f'{directory}/yolov8n.pt')
result = model.predict(source = '/content/cars.jpg',conf =0.25)
# Out:
# image 1/1 /content/cars.jpg: 448x640 26 cars, 111.4ms
# Speed: 4.8ms preprocess, 111.4ms inference, 2143.6ms postprocess per image at shape (1, 3, 448, 640)

# %%
image ='runs/detect/predict/cars.jpg'
Image(filename=image,height=500)

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25
source='/content/cars2.mp4'
# Out:
# WARNING ⚠️ 'source' argument is missing. Using default 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
# Ultralytics YOLOv8.2.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 128.0ms
# image 2/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 1 tie, 80.8ms
# Speed: 6.9ms preprocess, 104.4ms inference, 1116.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
image ='runs/detect/predict2/bus.jpg'
Image(filename=image,height=500)

# %%
image ='/content/runs/detect/predict2/zidane.jpg'
Image(filename=image,height=500)
